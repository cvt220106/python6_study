# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

# 查看各种包的版本
print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.9.1
# sys.version_info(major=3, minor=10, micro=4, releaselevel='final', serial=0)
# matplotlib 3.5.2
# numpy 1.23.1
# pandas 1.4.3
# sklearn 1.1.1
# tensorflow 2.9.1
# keras.api._v2.keras 2.9.0

# %% [markdown]
# 导入keras自带的衣服分类数据集

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 6us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 58s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 10s 2us/step
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# 对数据进行标准化,标准化数据只能传入二维<br>
# 因此先reshape(-1,1)处理数据后,再reshape(-1,28,28)不改变其本来形状

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train: [None, 28, 28] -> [None, 784]
x_train_scaled = scaler.fit_transform(
    x_train.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
x_valid_scaled = scaler.transform(
    x_valid.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
x_test_scaled = scaler.transform(
    x_test.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)

# %% [markdown]
# 建立神经网络层

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
#这次我们做20层
# 利用for循环实现多层
for _ in range(20):
    model.add(keras.layers.Dense(100, activation="relu"))
#结果层
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer = keras.optimizers.SGD(0.001),
              metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 100)               10100
#
#  dense_6 (Dense)             (None, 100)               10100
#
#  dense_7 (Dense)             (None, 100)               10100
#
#  dense_8 (Dense)             (None, 100)               10100
#
#  dense_9 (Dense)             (None, 100)               10100
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 100)               10100
#
#  dense_12 (Dense)            (None, 100)               10100
#
#  dense_13 (Dense)            (None, 100)               10100
#
#  dense_14 (Dense)            (None, 100)               10100
#
#  dense_15 (Dense)            (None, 100)               10100
#
#  dense_16 (Dense)            (None, 100)               10100
#
#  dense_17 (Dense)            (None, 100)               10100
#
#  dense_18 (Dense)            (None, 100)               10100
#
#  dense_19 (Dense)            (None, 100)               10100
#
#  dense_20 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 271,410
# Trainable params: 271,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers
# Out:
# [<keras.layers.reshaping.flatten.Flatten at 0x19832988b20>,
#  <keras.layers.core.dense.Dense at 0x198329889a0>,
#  <keras.layers.core.dense.Dense at 0x19832988940>,
#  <keras.layers.core.dense.Dense at 0x19833cb5a80>,
#  <keras.layers.core.dense.Dense at 0x19833cd2500>,
#  <keras.layers.core.dense.Dense at 0x198329b47f0>,
#  <keras.layers.core.dense.Dense at 0x19832aed4e0>,
#  <keras.layers.core.dense.Dense at 0x19832aec7f0>,
#  <keras.layers.core.dense.Dense at 0x19832aee920>,
#  <keras.layers.core.dense.Dense at 0x19832b1fe80>,
#  <keras.layers.core.dense.Dense at 0x19832b1fd30>,
#  <keras.layers.core.dense.Dense at 0x19832aecc40>,
#  <keras.layers.core.dense.Dense at 0x19832aee7d0>,
#  <keras.layers.core.dense.Dense at 0x19832aee890>,
#  <keras.layers.core.dense.Dense at 0x19832b3a260>,
#  <keras.layers.core.dense.Dense at 0x19832b392d0>,
#  <keras.layers.core.dense.Dense at 0x19832b1fbe0>,
#  <keras.layers.core.dense.Dense at 0x19832b1f8b0>,
#  <keras.layers.core.dense.Dense at 0x1980a708d60>,
#  <keras.layers.core.dense.Dense at 0x19832aed1b0>,
#  <keras.layers.core.dense.Dense at 0x19832b39420>,
#  <keras.layers.core.dense.Dense at 0x19832ab96f0>]

# %%
# earlystopping, ModelCheckpoint

callbacks = [
    keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3),
]
history = model.fit(x_train_scaled, y_train, epochs=100,
                    validation_data=(x_valid_scaled, y_valid),
                    callbacks = callbacks)
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 8s 3ms/step - loss: 2.3011 - accuracy: 0.2048 - val_loss: 2.2993 - val_accuracy: 0.2488
# Epoch 2/100
# 1719/1719 [==============================] - 6s 4ms/step - loss: 2.2963 - accuracy: 0.2307 - val_loss: 2.2921 - val_accuracy: 0.2242
# Epoch 3/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.2859 - accuracy: 0.2179 - val_loss: 2.2767 - val_accuracy: 0.2296
# Epoch 4/100
# 1719/1719 [==============================] - 6s 3ms/step - loss: 2.2644 - accuracy: 0.2108 - val_loss: 2.2459 - val_accuracy: 0.2262
# Epoch 5/100
# 1719/1719 [==============================] - 6s 3ms/step - loss: 2.2179 - accuracy: 0.2075 - val_loss: 2.1745 - val_accuracy: 0.2204
# Epoch 6/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.1001 - accuracy: 0.2042 - val_loss: 1.9823 - val_accuracy: 0.2184
# Epoch 7/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.7616 - accuracy: 0.2641 - val_loss: 1.4238 - val_accuracy: 0.3884
# Epoch 8/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.1927 - accuracy: 0.4832 - val_loss: 0.9924 - val_accuracy: 0.6172
# Epoch 9/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.9698 - accuracy: 0.5975 - val_loss: 0.9235 - val_accuracy: 0.6436
# Epoch 10/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8836 - accuracy: 0.6434 - val_loss: 1.0009 - val_accuracy: 0.5872
# Epoch 11/100
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.8223 - accuracy: 0.6783 - val_loss: 0.7835 - val_accuracy: 0.7142
# Epoch 12/100
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.7764 - accuracy: 0.7034 - val_loss: 1.4891 - val_accuracy: 0.4122
# Epoch 13/100
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.7281 - accuracy: 0.7235 - val_loss: 0.6834 - val_accuracy: 0.7352
# Epoch 14/100
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.6900 - accuracy: 0.7431 - val_loss: 0.6545 - val_accuracy: 0.7678
# Epoch 15/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6544 - accuracy: 0.7624 - val_loss: 0.6137 - val_accuracy: 0.7854
# Epoch 16/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6178 - accuracy: 0.7781 - val_loss: 0.6045 - val_accuracy: 0.7896
# Epoch 17/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5873 - accuracy: 0.7889 - val_loss: 0.6663 - val_accuracy: 0.7438
# Epoch 18/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5599 - accuracy: 0.8011 - val_loss: 0.5406 - val_accuracy: 0.8218
# Epoch 19/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.5308 - accuracy: 0.8162 - val_loss: 0.5264 - val_accuracy: 0.8260
# Epoch 20/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5066 - accuracy: 0.8256 - val_loss: 0.4892 - val_accuracy: 0.8374
# Epoch 21/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4786 - accuracy: 0.8345 - val_loss: 0.4704 - val_accuracy: 0.8388
# Epoch 22/100
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.4535 - accuracy: 0.8441 - val_loss: 0.4677 - val_accuracy: 0.8408
# Epoch 23/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4386 - accuracy: 0.8475 - val_loss: 0.4793 - val_accuracy: 0.8374
# Epoch 24/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4233 - accuracy: 0.8521 - val_loss: 0.4479 - val_accuracy: 0.8474
# Epoch 25/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4115 - accuracy: 0.8570 - val_loss: 0.4566 - val_accuracy: 0.8418
# Epoch 26/100
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3994 - accuracy: 0.8607 - val_loss: 0.4322 - val_accuracy: 0.8530
# Epoch 27/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3918 - accuracy: 0.8623 - val_loss: 0.4110 - val_accuracy: 0.8568
# Epoch 28/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3820 - accuracy: 0.8658 - val_loss: 0.4460 - val_accuracy: 0.8476
# Epoch 29/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3723 - accuracy: 0.8689 - val_loss: 0.4126 - val_accuracy: 0.8590
# Epoch 30/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.3644 - accuracy: 0.8715 - val_loss: 0.4331 - val_accuracy: 0.8566
# Epoch 31/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3571 - accuracy: 0.8744 - val_loss: 0.4035 - val_accuracy: 0.8634
# Epoch 32/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3514 - accuracy: 0.8760 - val_loss: 0.3983 - val_accuracy: 0.8656
# Epoch 33/100
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3443 - accuracy: 0.8784 - val_loss: 0.3969 - val_accuracy: 0.8638
# Epoch 34/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3377 - accuracy: 0.8821 - val_loss: 0.3970 - val_accuracy: 0.8622
# Epoch 35/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3323 - accuracy: 0.8818 - val_loss: 0.4033 - val_accuracy: 0.8634
# Epoch 36/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3265 - accuracy: 0.8848 - val_loss: 0.3970 - val_accuracy: 0.8670
# Epoch 37/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3218 - accuracy: 0.8857 - val_loss: 0.4086 - val_accuracy: 0.8622
# Epoch 38/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3180 - accuracy: 0.8869 - val_loss: 0.4077 - val_accuracy: 0.8592

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 3)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test, verbose=0)
# Out:
# [0.42423802614212036, 0.8535000085830688]
